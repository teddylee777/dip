# %% [markdown]
# ## 한글 폰트 설치
#
# - 참고: https://teddylee777.github.io/colab/colab-korean

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# - [서울교통공사_월별 승하차인원](https://www.data.go.kr/data/15044249/fileData.do)
# - [지하철역 주소 정보](http://data.seoul.go.kr/dataList/OA-12035/S/1/datasetView.do)

# %% [markdown]
# ## 모듈 import & 파일 로드

# %%
import os
import pandas as pd
import numpy as np
import requests
import json
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = 'NanumGothic'

DATA = 'data'

# 파일 로드
file1 = os.path.join(DATA, '서울교통공사_월별 승하차인원_20191231.csv')
df = pd.read_csv(file1, encoding='euc-kr')
df
# Out:
#       호선   역번호        역명       1월       2월       3월       4월       5월  \
# 0    1호선   150    서울역(1)  3364130  3026680  3446064  3473124  3563150
# 1    1호선   151     시청(1)  1562110  1275441  1581722  1635208  1666756
# 2    1호선   152        종각  2740119  2276059  2650404  2634617  2704398
# 3    1호선   153   종로3가(1)  2143877  1823175  2106819  2039389  2154261
# 4    1호선   154      종로5가  1701378  1452300  1733436  1703251  1749096
# ..   ...   ...       ...      ...      ...      ...      ...      ...
# 283  9호선  4134      송파나루   126242   112765   138597   146349   149438
# 284  9호선  4135      한성백제    71767    61579    75888    82032    96069
# 285  9호선  4136  올림픽공원(9)   200886   167697   238828   244474   283858
# 286  9호선  4137      둔촌오륜    29747    27600    38496    39962    40463
# 287  9호선  4138    중앙보훈병원   216541   188426   231958   252082   263683
#
#           6월       7월       8월       9월      10월      11월      12월
# 0    3302692  3402309  3384029  3205334  3589014  3496294  3543766
# 1    1527076  1586068  1592866  1463466  1875878  1691849  1744402
# 2    2458042  2716809  2625393  2354321  2789296  2629753  2875434
# 3    1989308  2092865  1987469  1843767  2129128  1995373  2133123
# 4    1583541  1617625  1571120  1493315  1754767  1673923  1748656
# ..       ...      ...      ...      ...      ...      ...      ...
# 283   138761   154548   153004   139389   156361   159925   173431
# 284    81802    86838    86604    91050   101864    98105    97581
# 285   282596   292005   284730   244540   291573   292314   313639
# 286    39044    40986    38286    40227    43596    44182    43115
# 287   248612   276292   274651   272538   319228   314536   320079
#
# [288 rows x 15 columns]

# %% [markdown]
# ## 역명에 대한 클린징

# %%
import re

# Regular Expression 적용하여 ()괄호를 제거 후 추출
pattern_string = r'.+(?=\()'
pattern = re.compile(pattern_string)

# %%
pattern.match('올림픽공원(9)').group().strip()
# Out:
# '올림픽공원'

# %%
def clean_station(x):
    location = pattern.match(x)
    if location:
        loc = location.group().strip()
    else:
        loc = x
    return loc

# %%
df['역명_clean'] = df['역명'].apply(clean_station)
df[['역명_clean', '역명']].head(10)
# Out:
#   역명_clean       역명
# 0      서울역   서울역(1)
# 1       시청    시청(1)
# 2       종각       종각
# 3     종로3가  종로3가(1)
# 4     종로5가     종로5가
# 5      동대문   동대문(1)
# 6      신설동   신설동(1)
# 7      제기동      제기동
# 8      청량리      청량리
# 9      동묘앞   동묘앞(1)

# %%
df = df.drop('역명', axis=1)
df = df.rename({'역명_clean':'역명'}, axis=1)
df.head()
# Out:
#     호선  역번호       1월       2월       3월       4월       5월       6월       7월  \
# 0  1호선  150  3364130  3026680  3446064  3473124  3563150  3302692  3402309
# 1  1호선  151  1562110  1275441  1581722  1635208  1666756  1527076  1586068
# 2  1호선  152  2740119  2276059  2650404  2634617  2704398  2458042  2716809
# 3  1호선  153  2143877  1823175  2106819  2039389  2154261  1989308  2092865
# 4  1호선  154  1701378  1452300  1733436  1703251  1749096  1583541  1617625
#
#         8월       9월      10월      11월      12월    역명
# 0  3384029  3205334  3589014  3496294  3543766   서울역
# 1  1592866  1463466  1875878  1691849  1744402    시청
# 2  2625393  2354321  2789296  2629753  2875434    종각
# 3  1987469  1843767  2129128  1995373  2133123  종로3가
# 4  1571120  1493315  1754767  1673923  1748656  종로5가

# %% [markdown]
# ## 중복 되는 역에 대한 승하차 인원 합계 환산

# %%
df.loc[df['역명'] == '서울역']
# Out:
#       호선  역번호       1월       2월       3월       4월       5월       6월       7월  \
# 0    1호선  150  3364130  3026680  3446064  3473124  3563150  3302692  3402309
# 110  4호선  426  1105093   973842  1167990  1164404  1174031  1091847  1138933
#
#           8월       9월      10월      11월      12월   역명
# 0    3384029  3205334  3589014  3496294  3543766  서울역
# 110  1121257  1056526  1201541  1181427  1204728  서울역

# %%
df.loc[df['역명'] == '고속터미널']
# Out:
#       호선   역번호       1월       2월       3월       4월       5월       6월       7월  \
# 79   3호선   329  3650330  3443565  3763343  3549653  3881177  3578839  3659723
# 232  7호선  2736  1200218  1091379  1203247  1187192  1245421  1153031  1185762
#
#           8월       9월      10월      11월      12월     역명
# 79   3830191  3512161  3719899  3732376  3933493  고속터미널
# 232  1190917  1143816  1258013  1231791  1236209  고속터미널

# %%
df_total = df.groupby('역명').sum().reset_index().drop('역번호', axis=1)
df_total
# Out:
#           역명       1월       2월       3월       4월       5월       6월       7월  \
# 0       가락시장  1172018   961948  1153158  1166383  1161625  1072459  1124263
# 1    가산디지털단지  2558564  2083546  2442252  2520173  2507799  2262116  2558788
# 2         강남  6731617  5537751  6234948  6070160  6247693  5876947  6809521
# 3       강남구청   980057   802269   977457   995296  1008723   928293   997659
# 4         강동  1145633   972550  1186391  1193841  1222583  1140184  1233732
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 246       홍제  1131352   977157  1235738  1241081  1272282  1143038  1154822
# 247       화곡  1762766  1510610  1826195  1854362  1897859  1737139  1822525
# 248      화랑대   660606   560735   748303   757517   792196   689357   694126
# 249       회현  1864182  1574625  2027233  2050713  2096872  1909038  1950431
# 250    효창공원앞   417656   354668   460922   472453   472657   422006   424261
#
#           8월       9월      10월      11월      12월
# 0    1056539  1043442  1163322  1170635  1221485
# 1    2300971  2218934  2459146  2467699  2430534
# 2    6363167  5458954  6073476  6027683  6361642
# 3     931419   886769  1007349  1005622   998240
# 4    1166811  1118171  1253802  1231872  1244817
# ..       ...      ...      ...      ...      ...
# 246  1097604  1108654  1233937  1193338  1177045
# 247  1717743  1656990  1839997  1791497  1828432
# 248   651611   687711   770130   748711   718661
# 249  1825184  1719782  2062291  1943588  1952633
# 250   386363   397740   467549   444927   438327
#
# [251 rows x 13 columns]

# %% [markdown]
# 중복 역명에 대하여 `keep=first`로 중복 데이터 제거

# %%
df.drop_duplicates('역명', keep='first')
# Out:
#       호선   역번호       1월       2월       3월       4월       5월       6월       7월  \
# 0    1호선   150  3364130  3026680  3446064  3473124  3563150  3302692  3402309
# 1    1호선   151  1562110  1275441  1581722  1635208  1666756  1527076  1586068
# 2    1호선   152  2740119  2276059  2650404  2634617  2704398  2458042  2716809
# 3    1호선   153  2143877  1823175  2106819  2039389  2154261  1989308  2092865
# 4    1호선   154  1701378  1452300  1733436  1703251  1749096  1583541  1617625
# ..   ...   ...      ...      ...      ...      ...      ...      ...      ...
# 281  9호선  4132   153298   138261   170690   176614   184567   173087   190832
# 283  9호선  4134   126242   112765   138597   146349   149438   138761   154548
# 284  9호선  4135    71767    61579    75888    82032    96069    81802    86838
# 286  9호선  4137    29747    27600    38496    39962    40463    39044    40986
# 287  9호선  4138   216541   188426   231958   252082   263683   248612   276292
#
#           8월       9월      10월      11월      12월      역명
# 0    3384029  3205334  3589014  3496294  3543766     서울역
# 1    1592866  1463466  1875878  1691849  1744402      시청
# 2    2625393  2354321  2789296  2629753  2875434      종각
# 3    1987469  1843767  2129128  1995373  2133123    종로3가
# 4    1571120  1493315  1754767  1673923  1748656    종로5가
# ..       ...      ...      ...      ...      ...     ...
# 281   186392   174230   193734   196619   205636    석촌고분
# 283   153004   139389   156361   159925   173431    송파나루
# 284    86604    91050   101864    98105    97581    한성백제
# 286    38286    40227    43596    44182    43115    둔촌오륜
# 287   274651   272538   319228   314536   320079  중앙보훈병원
#
# [251 rows x 15 columns]

# %%
df_merged = pd.merge(df_total, df.drop_duplicates('역명', keep='first')[['역명', '역번호']], how='left')
df_merged
# Out:
#           역명       1월       2월       3월       4월       5월       6월       7월  \
# 0       가락시장  1172018   961948  1153158  1166383  1161625  1072459  1124263
# 1    가산디지털단지  2558564  2083546  2442252  2520173  2507799  2262116  2558788
# 2         강남  6731617  5537751  6234948  6070160  6247693  5876947  6809521
# 3       강남구청   980057   802269   977457   995296  1008723   928293   997659
# 4         강동  1145633   972550  1186391  1193841  1222583  1140184  1233732
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 246       홍제  1131352   977157  1235738  1241081  1272282  1143038  1154822
# 247       화곡  1762766  1510610  1826195  1854362  1897859  1737139  1822525
# 248      화랑대   660606   560735   748303   757517   792196   689357   694126
# 249       회현  1864182  1574625  2027233  2050713  2096872  1909038  1950431
# 250    효창공원앞   417656   354668   460922   472453   472657   422006   424261
#
#           8월       9월      10월      11월      12월   역번호
# 0    1056539  1043442  1163322  1170635  1221485   340
# 1    2300971  2218934  2459146  2467699  2430534  2748
# 2    6363167  5458954  6073476  6027683  6361642   222
# 3     931419   886769  1007349  1005622   998240  2732
# 4    1166811  1118171  1253802  1231872  1244817  2549
# ..       ...      ...      ...      ...      ...   ...
# 246  1097604  1108654  1233937  1193338  1177045   314
# 247  1717743  1656990  1839997  1791497  1828432  2518
# 248   651611   687711   770130   748711   718661  2647
# 249  1825184  1719782  2062291  1943588  1952633   425
# 250   386363   397740   467549   444927   438327  2628
#
# [251 rows x 14 columns]

# %% [markdown]
# **고속터미널** 역에 대한 합계치 비교

# %%
df.loc[df['역명'] == '고속터미널']
# Out:
#       호선   역번호       1월       2월       3월       4월       5월       6월       7월  \
# 79   3호선   329  3650330  3443565  3763343  3549653  3881177  3578839  3659723
# 232  7호선  2736  1200218  1091379  1203247  1187192  1245421  1153031  1185762
#
#           8월       9월      10월      11월      12월     역명
# 79   3830191  3512161  3719899  3732376  3933493  고속터미널
# 232  1190917  1143816  1258013  1231791  1236209  고속터미널

# %%
df_merged.loc[df_merged['역명'] == '고속터미널']
# Out:
#        역명       1월       2월       3월       4월       5월       6월       7월  \
# 15  고속터미널  4850548  4534944  4966590  4736845  5126598  4731870  4845485
#
#          8월       9월      10월      11월      12월  역번호
# 15  5021108  4655977  4977912  4964167  5169702  329

# %% [markdown]
# ## `seoul_station_geocode.csv` 파일 로드

# %%
address = pd.read_csv('seoul_station_geocode.csv')
address.head()
# Out:
#    호선    역명        lat         lng                    주소  역번호
# 0   1   서울역  37.564119  126.976808    서울특별시 중구 세종대로 지하 2  150
# 1   1    시청  37.565704  126.976862  서울특별시 중구 세종대로 지하 101  151
# 2   1    종각  37.570169  126.983099    서울특별시 종로구 종로 지하 55  152
# 3   1  종로3가  37.570436  126.992148   서울특별시 종로구 종로 지하 129  153
# 4   1  종로5가  37.572590  126.999912   서울특별시 종로구 종로 지하 216  154

# %%
merged_data = pd.merge(df_merged, address[['주소', '역명', 'lat', 'lng']], on='역명', how='left')
merged_data.head()
# Out:
#         역명       1월       2월       3월       4월       5월       6월       7월  \
# 0     가락시장  1172018   961948  1153158  1166383  1161625  1072459  1124263
# 1  가산디지털단지  2558564  2083546  2442252  2520173  2507799  2262116  2558788
# 2       강남  6731617  5537751  6234948  6070160  6247693  5876947  6809521
# 3     강남구청   980057   802269   977457   995296  1008723   928293   997659
# 4       강동  1145633   972550  1186391  1193841  1222583  1140184  1233732
#
#         8월       9월      10월      11월      12월   역번호                     주소  \
# 0  1056539  1043442  1163322  1170635  1221485   340  서울특별시 송파구 송파대로 지하 257
# 1  2300971  2218934  2459146  2467699  2430534  2748      서울특별시 금천구 벚꽃로 309
# 2  6363167  5458954  6073476  6027683  6361642   222  서울특별시 강남구 강남대로 지하 396
# 3   931419   886769  1007349  1005622   998240  2732    서울특별시 강남구 학동로 지하346
# 4  1166811  1118171  1253802  1231872  1244817  2549  서울특별시 강동구 천호대로 지하1097
#
#          lat         lng
# 0  37.492663  127.118544
# 1  37.482255  126.882183
# 2  37.497786  127.027777
# 3  37.517133  127.041299
# 4  37.537595  127.125370

# %%
df_merged.shape, merged_data.shape
# Out:
# ((251, 14), (251, 17))

# %% [markdown]
# 병합된 데이터셋에 대한 결측치 확인

# %%
merged_data.isnull().sum()
# Out:
# 역명     0
# 1월     0
# 2월     0
# 3월     0
# 4월     0
# 5월     0
# 6월     0
# 7월     0
# 8월     0
# 9월     0
# 10월    0
# 11월    0
# 12월    0
# 역번호    0
# 주소     0
# lat    0
# lng    0
# dtype: int64

# %% [markdown]
# ## 주소 데이터 분할

# %%
merged_data['주소'].str.split()
# Out:
# 0        [서울특별시, 송파구, 송파대로, 지하, 257]
# 1             [서울특별시, 금천구, 벚꽃로, 309]
# 2        [서울특별시, 강남구, 강남대로, 지하, 396]
# 3           [서울특별시, 강남구, 학동로, 지하346]
# 4         [서울특별시, 강동구, 천호대로, 지하1097]
#                    ...
# 246    [서울특별시, 서대문구, 통일로, 지하, 440-1]
# 247         [서울특별시, 강서구, 화곡로, 지하168]
# 248         [서울특별시, 노원구, 화랑로, 지하510]
# 249         [서울특별시, 중구, 퇴계로, 지하, 54]
# 250         [서울특별시, 용산구, 백범로, 지하287]
# Name: 주소, Length: 251, dtype: object

# %% [markdown]
# **구**만 추출하기

# %%
merged_data['주소'].str.split().str[1]
# Out:
# 0       송파구
# 1       금천구
# 2       강남구
# 3       강남구
# 4       강동구
#        ...
# 246    서대문구
# 247     강서구
# 248     노원구
# 249      중구
# 250     용산구
# Name: 주소, Length: 251, dtype: object

# %%
merged_data['구'] = merged_data['주소'].str.split().str[1]
merged_data['구']
# Out:
# 0       송파구
# 1       금천구
# 2       강남구
# 3       강남구
# 4       강동구
#        ...
# 246    서대문구
# 247     강서구
# 248     노원구
# 249      중구
# 250     용산구
# Name: 구, Length: 251, dtype: object

# %%
merged_data.head()
# Out:
#         역명       1월       2월       3월       4월       5월       6월       7월  \
# 0     가락시장  1172018   961948  1153158  1166383  1161625  1072459  1124263
# 1  가산디지털단지  2558564  2083546  2442252  2520173  2507799  2262116  2558788
# 2       강남  6731617  5537751  6234948  6070160  6247693  5876947  6809521
# 3     강남구청   980057   802269   977457   995296  1008723   928293   997659
# 4       강동  1145633   972550  1186391  1193841  1222583  1140184  1233732
#
#         8월       9월      10월      11월      12월   역번호                     주소  \
# 0  1056539  1043442  1163322  1170635  1221485   340  서울특별시 송파구 송파대로 지하 257
# 1  2300971  2218934  2459146  2467699  2430534  2748      서울특별시 금천구 벚꽃로 309
# 2  6363167  5458954  6073476  6027683  6361642   222  서울특별시 강남구 강남대로 지하 396
# 3   931419   886769  1007349  1005622   998240  2732    서울특별시 강남구 학동로 지하346
# 4  1166811  1118171  1253802  1231872  1244817  2549  서울특별시 강동구 천호대로 지하1097
#
#          lat         lng    구
# 0  37.492663  127.118544  송파구
# 1  37.482255  126.882183  금천구
# 2  37.497786  127.027777  강남구
# 3  37.517133  127.041299  강남구
# 4  37.537595  127.125370  강동구

# %% [markdown]
# ## folium을 활용한 지도 시각화

# %%
import folium

# %%
# 위도
latitude = 37.394946
# 경도
longitude = 127.111104

# %%
m = folium.Map(location=[latitude, longitude],
               zoom_start=17, 
               width=750, 
               height=500
              )
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2b5b1a9a5c1a4ad4ad1e67016120d72f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20750.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20500.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2b5b1a9a5c1a4ad4ad1e67016120d72f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2b5b1a9a5c1a4ad4ad1e67016120d72f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2b5b1a9a5c1a4ad4ad1e67016120d72f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.394946%2C%20127.111104%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
station_name = '시청'
geo = list(merged_data.loc[merged_data['역명'] == station_name, ['lat', 'lng']].iloc[0])
print(f'위도: {geo[0]}, 경도: {geo[1]}')

# folium 시각화
m = folium.Map(location=geo,
               zoom_start=17, 
               width=750, 
               height=500
              )

folium.Marker(geo,
              popup=station_name,
              tooltip=f'{station_name} 정보').add_to(m)
m
# Out:
# 위도: 37.5657037, 경도: 126.9768616
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ffa1a8e27e0d434d9d99124f5ce9bc97%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20750.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20500.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ffa1a8e27e0d434d9d99124f5ce9bc97%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ffa1a8e27e0d434d9d99124f5ce9bc97%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ffa1a8e27e0d434d9d99124f5ce9bc97%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5657037%2C%20126.9768616%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
m = folium.Map(
    location=[37.559819, 126.963895],
    zoom_start=11, 
    tiles='cartodbpositron'
)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a807b4655e7d4a2d8ce81face0131d4d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a807b4655e7d4a2d8ce81face0131d4d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a807b4655e7d4a2d8ce81face0131d4d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a807b4655e7d4a2d8ce81face0131d4d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.559819%2C%20126.963895%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ## 서울 행정구역 표기 및 시각화에 boundary 적용

# %%
# 서울 행정구역 json raw파일(githubcontent)
r = requests.get('https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json')
c = r.content
seoul_geo = json.loads(c)

# %%
merged_data.groupby('구')['1월'].sum()
# Out:
# 구
# 강남구     31986874
# 강동구      9048155
# 강북구      5068922
# 강서구      7773009
# 고양시        74540
# 관악구     10851160
# 광명시      3106352
# 광진구     13114539
# 구로구     12282568
# 금천구      2558564
# 노원구     11458963
# 도봉구      4324439
# 동대문구     5587312
# 동작구     13309604
# 마포구     20015277
# 부천시      3895473
# 부평구      1551686
# 서대문구     2826656
# 서초구     17082128
# 성남시      2678442
# 성동구      9481839
# 성북구      6871698
# 송파구     19002401
# 양천구      4549536
# 영등포구     8185652
# 용산구      5642065
# 은평구     10222817
# 의정부시       96454
# 종로구     21171875
# 중구      26309294
# 중랑구      5279966
# Name: 1월, dtype: int64

# %%
# 월 설정
N = 2

plt.figure(figsize=(12, 15))
merged_data.groupby('구')[f'{N}월'].sum().sort_values().plot(kind='barh')
plt.title(f'{N}월 구별 승하차 인원')
plt.show()

# %%
m = folium.Map(
    location=[37.559819, 126.963895],
    zoom_start=10, 
    tiles='cartodbpositron'
)

folium.GeoJson(
    seoul_geo,
    name='지역구'
).add_to(m)

m.choropleth(geo_data=seoul_geo,
             data=merged_data.groupby('구')[f'{N}월'].sum(),
             fill_color='YlOrRd', # 색상 변경도 가능하다
             fill_opacity=0.9,
             line_opacity=0.2,
             key_on='properties.name',
             legend_name=f'{N}월 승하차 인원', 
            )
m
# Out:
# /opt/conda/envs/py37/lib/python3.7/site-packages/folium/folium.py:413: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c457e2f33231421fb19baf92456d4584%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c457e2f33231421fb19baf92456d4584%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c457e2f33231421fb19baf92456d4584%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c457e2f33231421fb19baf92456d4584%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## 통계 분석

# %%
stats = merged_data.drop(['주소', '역번호', 'lat', 'lng'], axis=1)
stats
# Out:
#           역명       1월       2월       3월       4월       5월       6월       7월  \
# 0       가락시장  1172018   961948  1153158  1166383  1161625  1072459  1124263
# 1    가산디지털단지  2558564  2083546  2442252  2520173  2507799  2262116  2558788
# 2         강남  6731617  5537751  6234948  6070160  6247693  5876947  6809521
# 3       강남구청   980057   802269   977457   995296  1008723   928293   997659
# 4         강동  1145633   972550  1186391  1193841  1222583  1140184  1233732
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 246       홍제  1131352   977157  1235738  1241081  1272282  1143038  1154822
# 247       화곡  1762766  1510610  1826195  1854362  1897859  1737139  1822525
# 248      화랑대   660606   560735   748303   757517   792196   689357   694126
# 249       회현  1864182  1574625  2027233  2050713  2096872  1909038  1950431
# 250    효창공원앞   417656   354668   460922   472453   472657   422006   424261
#
#           8월       9월      10월      11월      12월     구
# 0    1056539  1043442  1163322  1170635  1221485   송파구
# 1    2300971  2218934  2459146  2467699  2430534   금천구
# 2    6363167  5458954  6073476  6027683  6361642   강남구
# 3     931419   886769  1007349  1005622   998240   강남구
# 4    1166811  1118171  1253802  1231872  1244817   강동구
# ..       ...      ...      ...      ...      ...   ...
# 246  1097604  1108654  1233937  1193338  1177045  서대문구
# 247  1717743  1656990  1839997  1791497  1828432   강서구
# 248   651611   687711   770130   748711   718661   노원구
# 249  1825184  1719782  2062291  1943588  1952633    중구
# 250   386363   397740   467549   444927   438327   용산구
#
# [251 rows x 14 columns]

# %%
stats.loc[stats['역명'] == '강남']
# Out:
#    역명       1월       2월       3월       4월       5월       6월       7월       8월  \
# 2  강남  6731617  5537751  6234948  6070160  6247693  5876947  6809521  6363167
#
#         9월      10월      11월      12월    구
# 2  5458954  6073476  6027683  6361642  강남구

# %%
stats.loc[stats['역명'] == '강남'].iloc[:, 1:-1]
# Out:
#         1월       2월       3월       4월       5월       6월       7월       8월  \
# 2  6731617  5537751  6234948  6070160  6247693  5876947  6809521  6363167
#
#         9월      10월      11월      12월
# 2  5458954  6073476  6027683  6361642

# %% [markdown]
# [seaborn pointplot](https://seaborn.pydata.org/generated/seaborn.pointplot.html)

# %%
place = '강남'
plt.figure(figsize=(10, 6))
sns.pointplot(x = np.arange(1, 13), y=np.squeeze(stats.loc[stats['역명'] == place].iloc[:, 1:-1].values))
plt.show()

# %%
place1 = '강남'
place2 = '고속터미널'
plt.figure(figsize=(10, 6))
sns.pointplot(x = np.arange(1, 13), y=np.squeeze(stats.loc[stats['역명'] == place1].iloc[:, 1:-1].values), color='black')
sns.pointplot(x = np.arange(1, 13), y=np.squeeze(stats.loc[stats['역명'] == place2].iloc[:, 1:-1].values), color='tomato')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.pointplot(x ='역명', y='1월', data=stats.loc[stats['구'] == '강남구'].iloc[:, :-1], color='black')
sns.pointplot(x ='역명', y='4월', data=stats.loc[stats['구'] == '강남구'].iloc[:, :-1], color='blue')
sns.pointplot(x ='역명', y='7월', data=stats.loc[stats['구'] == '강남구'].iloc[:, :-1], color='tomato')
sns.pointplot(x ='역명', y='11월', data=stats.loc[stats['구'] == '강남구'].iloc[:, :-1], color='cyan')
plt.show()

# %%
import seaborn as sns

# %%
stats.loc[stats['구'] == '강남구'].iloc[:, :-1]
# Out:
#        역명       1월       2월       3월       4월       5월       6월       7월  \
# 2      강남  6731617  5537751  6234948  6070160  6247693  5876947  6809521
# 3    강남구청   980057   802269   977457   995296  1008723   928293   997659
# 46     논현  1272566  1028376  1221938  1242691  1252265  1154789  1282475
# 52     대청   571540   489011   613628   629477   632760   581510   630489
# 53     대치   771395   654803   781607   755131   793345   725059   795810
# 55     도곡   351438   288849   362532   382806   377713   341816   357485
# 78     매봉   693514   563078   685371   719930   708979   652900   712314
# 100   봉은사   576278   491407   600983   609758   654489   593663   696649
# 112    삼성  3719644  3046293  3643736  3729855  3893301  3487738  4068679
# 113  삼성중앙   200898   164486   198459   205198   204579   188419   214900
# 131    선릉  3286131  2594587  3108392  3219288  3212656  2975142  3370008
# 132   선정릉   287483   238817   288820   298682   299811   277253   312912
# 139    수서  1138492   973848  1165731  1174262  1197004  1112665  1159326
# 153    신사  2169024  1827042  2113324  2078134  2178651  2023068  2183593
# 168   압구정  2198264  1825967  2160331  2147641  2168041  2059888  2219859
# 175    언주   321121   260766   305311   312469   308276   291600   334560
# 178    역삼  3259350  2572602  3058210  3127413  3065235  2830731  3290039
# 203    일원   598043   494352   611878   639272   646212   591257   640800
# 229    청담  1308555  1075177  1295954  1331681  1338220  1217362  1313725
# 236    학동  1394383  1113727  1344574  1380925  1380876  1257230  1390908
# 237   학여울   157081   125017   195229   210726   189640   163414   171440
#
#           8월       9월      10월      11월      12월
# 2    6363167  5458954  6073476  6027683  6361642
# 3     931419   886769  1007349  1005622   998240
# 46   1190215  1116400  1242568  1238770  1256900
# 52    578969   570768   622584   634588   638749
# 53    773877   733876   801589   784258   727270
# 55    325844   327832   375562   377662   377118
# 78    650121   629730   708523   700965   710419
# 100   655613   559641   654507   683500   771233
# 112  3711200  3219226  3716093  3818749  4177583
# 113   206399   191583   213799   218291   222865
# 131  3078126  2834429  3201769  3209916  3249951
# 132   293349   274559   314976   317495   319144
# 139  1111535  1093986  1208022  1212336  1214318
# 153  2096807  1892380  2132440  2108700  2213851
# 168  2079724  1971140  2220785  2178771  2286090
# 175   318866   288496   327801   331789   342239
# 178  3011067  2757027  3085776  3081131  3137771
# 203   592542   581401   643041   645299   637219
# 229  1211705  1155875  1318212  1313577  1305782
# 236  1290326  1237867  1405677  1404703  1388541
# 237   164665   149240   148522   195963   211459

# %%
plt.figure(figsize=(12, 12))
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
sns.heatmap(stats.loc[stats['구'] == '강남구'].iloc[:, 1:-1]/1000, annot=True, fmt='.1f', cmap=cmap, cbar_kws={"shrink": .7})
plt.yticks(np.arange(len(stats.loc[stats['구'] == '강남구'].iloc[:, 0].values)), stats.loc[stats['구'] == '강남구'].iloc[:, 0].values)
plt.yticks(rotation=45)
plt.show()

# %%
avg = stats.loc[stats['구'] == '강남구'].iloc[:, 1:-1].mean()
avg
# Out:
# 1월     1.523184e+06
# 2월     1.246106e+06
# 3월     1.474686e+06
# 4월     1.488609e+06
# 5월     1.512308e+06
# 6월     1.396702e+06
# 7월     1.569198e+06
# 8월     1.458835e+06
# 9월     1.330056e+06
# 10월    1.496337e+06
# 11월    1.499513e+06
# 12월    1.549923e+06
# dtype: float64

# %%
place1 = '강남'
plt.figure(figsize=(10, 6))
sns.pointplot(x = np.arange(1, 13), y=np.squeeze(stats.loc[stats['역명'] == place1].iloc[:, 1:-1].values), color='black')
sns.pointplot(x = np.arange(1, 13), y=np.squeeze(avg.values), color='tomato')
plt.show()

# %%
gangnam = stats.loc[stats['역명'] == place1].iloc[:, 1:-1].values
gangnam
# Out:
# array([[6731617, 5537751, 6234948, 6070160, 6247693, 5876947, 6809521,
#         6363167, 5458954, 6073476, 6027683, 6361642]])

# %%
gangnam_norm = (gangnam - gangnam.min()) / (gangnam.max() - gangnam.min())
gangnam_norm
# Out:
# array([[0.94231756, 0.05834364, 0.57456905, 0.45255511, 0.58400583,
#         0.30949446, 1.        , 0.66950621, 0.        , 0.45501038,
#         0.42110388, 0.66837706]])

# %%
avg = avg.values
avg
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1194474/3070531446.py in <module>
# ----> 1 avg = avg.values
#       2 avg
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
avg_norm = (avg - avg.min()) / (avg.max() - avg.min())
avg_norm
# Out:
# array([0.85758474, 0.        , 0.70747831, 0.75057119, 0.82392115,
#        0.46610958, 1.        , 0.65841706, 0.25983393, 0.77448833,
#        0.7843185 , 0.9403432 ])

# %%
place1 = '강남'
plt.figure(figsize=(10, 6))
sns.pointplot(x = np.arange(1, 13), y=np.squeeze(gangnam_norm), color='black')
sns.pointplot(x = np.arange(1, 13), y=np.squeeze(avg_norm), color='tomato')
plt.show()
